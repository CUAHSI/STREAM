# %%
# !pixi init
# Out:
# Error:   × pixi.toml already exists

# %%
# !pixi add python=3.12 s3fs xarray tqdm geopandas jupyterlab pixi-kernel "setuptools<70" pygments pyarrow matplotlib seaborn
# Out:
# ▪ solving              [────────────────────]  0/1
# ▪ solving              [────────────────────]  0/1
# ▪ solving              [────────────────────]  0/1
# ▪ solving              [────────────────────]  0/1
# ▪ solving              [────────────────────]  0/1
# ▪ solving              [────────────────────]  0/1
# ▪ solving              [────────────────────]  0/1
# ⠁ fetching repodata    [────────────────────] @ 0B/s    0/3
# ▪ solving              [────────────────────]  0/1
# ⠁ fetching repodata    [────────────────────] @ 7.7 MiB/s/3
# ▪ solving              [────────────────────]  0/1
# ⠁ fetching repodata    [╾───────────────────] @ 7.7 MiB/s/3
# ▪ solving              [────────────────────]  0/1
# ⠁ fetching repodata    [╾───────────────────] @ 7.6 MiB/s/3
# ▪ solving              [────────────────────]  0/1
# ⠁ fetching repodata    [╾───────────────────] @ 7.6 MiB/s/3
# ▪ solving              [────────────────────]  0/1
# ...

# %%
# !pixi add --pypi hsclient
# Out:
# ▪ solving              [────────────────────]  0/1
# ▪ solving              [────────────────────]  0/1
# ▪ solving              [────────────────────]  0/1
# ⠁ solving              [────────────────────]  0/1  default (osx-arm64)
# ⠁ solving              [────────────────────]  0/1  default (osx-arm64)
# ⠉ solving              [────────────────────]  0/1  default (osx-arm64)
# ⠉ solving              [────────────────────]  0/1  default (osx-arm64)
# ⠉ solving              [────────────────────]  0/1  default (osx-arm64)
# ⠙ solving              [────────────────────]  0/1  default (osx-arm64)
# ⠙ solving              [────────────────────]  0/1  default (osx-arm64)
# ⠙ solving              [────────────────────]  0/1  default (osx-arm64)
# ▪ solving              [━━━━━━━━━━━━━━━━━━━━]  1/1
# ▪ solving              [━━━━━━━━━━━━━━━━━━━━]  1/1
# ▪ solving              [━━━━━━━━━━━━━━━━━━━━]  1/1
# ▪ solving              [━━━━━━━━━━━━━━━━━━━━]  1/1
# ...

# %%
# !pixi run start
