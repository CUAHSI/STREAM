# %% [markdown]
# The purpose of this notebook is to include additional attributes to the `01_metadata.csv` to facilitate search and discovery. The types of attributes may include huc identifiers, nhd stream comids, etc.

# %%
import pandas
from pathlib import Path
import pyarrow.parquet as pq
import requests
#from tqdm import tqdm
from tqdm.notebook import tqdm

# %%
table = pq.read_table(
    "data_parquet/metadata.parquet",
    use_pandas_metadata=False
)

df = table.to_pandas()

# %%
df.dtypes
# Out:
# STREAM_ID             object
# SourceID              object
# site name             object
# source                object
# latitude_wgs84       float64
# longitude_wgs84      float64
# State Code            object
# State                 object
# drainagearea_sqkm    float64
# geometry              object
# dtype: object

# %% [markdown]
# Loop over each site in the metadata file and query HUC attributes from geoconnex

# %%
def call_geoconnex(url):
    req = requests.get(url)
    
    # if a non-200 code is returned, skip the site.
    if req.status_code != 200:
        print(f'Error processing gauge {row.STREAM_ID}: {url}')
        errors[row.STREAM_ID] = req.text

    # get the response in JSON to make processing the data easier
    return req.json()

def get_geoconnex_metadata(df, 
                           service='hu06', 
                           result_key='huc6', 
                           buffer = 0.00001,
                           buffer_increment=0.0005,
                           retries = 5,
                           base_url='https://reference.geoconnex.us/collections', 
                           output_format='json'):
    attributes = {}
    errors = {}
    
    for idx, row in tqdm(df.iterrows(), total=len(df)):
 
        lat = row.latitude_wgs84
        lon = row.longitude_wgs84
        
        # build a bounding box that surrounds the lat/lon using the format
        # min_lon, min_lat, max_lon, max_lat. Buffer these points.
        bbox = f'{lon-buffer},{lat-buffer},{lon+buffer},{lat+buffer}'
    
        url = f'{base_url}/{service}/items?f={output_format}&bbox={bbox}' 

        res = call_geoconnex(url)
        # req = requests.get(url)
    
        # # if a non-200 code is returned, skip the site.
        # if req.status_code != 200:
        #     print(f'Error processing gauge {row.STREAM_ID}: {url}')
        #     errors[row.STREAM_ID] = req.text
        #     continue
    
        # # get the response in JSON to make processing the data easier
        # res = req.json()

        if res['numberReturned'] == 0:
            retry = 1
            while retry <= retries:
                retry += 1
                lat = row.latitude_wgs84
                lon = row.longitude_wgs84
                
                bbox = f'{lon-(buffer + retry*buffer_increment)},{lat-(buffer + retry*buffer_increment)},{lon+(buffer + retry*buffer_increment)},{lat+ (buffer + retry*buffer_increment)}'
                url = f'{base_url}/{service}/items?f={output_format}&bbox={bbox}' 
                res = call_geoconnex(url)

                if res['numberReturned'] > 0:
                    break
                
                    
        # if more than one object is returned, notify the user and then skip the site.
        if res['numberReturned'] != 1:    
            print(f'Gauge {row.STREAM_ID} returned {res["numberReturned"]} features. Skipping because I dont know what to do with this')
            errors[row.STREAM_ID] = res
            continue
    
        
        attributes[idx] = res['features'][0]['properties'][result_key] 

    return attributes, errors

# %%
attribs, errors = get_geoconnex_metadata(df, 'hu06', 'huc6')
# Out:
#   0%|          | 0/539 [00:00<?, ?it/s]

# %%
print(f'Found {len(errors)} errors')
# Out:
# Found 0 errors

# %%
df['huc06'] = df.index.map(attribs)

# %%
attribs, errors = get_geoconnex_metadata(df, 'hu12', 'huc12')
# Out:
#   0%|          | 0/539 [00:00<?, ?it/s]

# %%
df['huc12'] = df.index.map(attribs)

# %%
attribs, errors = get_geoconnex_metadata(df, 'mainstems', 'head_nhdpv2_comid', buffer=0.0001, retries=10)
# Out:
#   0%|          | 0/539 [00:00<?, ?it/s]
# Gauge STREAM-gauge-1637 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1639 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1671 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1693 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1698 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1704 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1705 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1708 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1711 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1717 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1718 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1719 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1734 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1779 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1804 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1810 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1829 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1830 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1838 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1842 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1868 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1877 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1881 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1882 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1900 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1903 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1915 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1918 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1921 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1922 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1931 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1937 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1938 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1942 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1943 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1953 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1957 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1960 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1969 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1970 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1971 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1972 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1974 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1984 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1987 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1992 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1998 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2028 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2044 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2050 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2057 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2058 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2060 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2072 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2104 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2112 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2113 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2114 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2141 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2144 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2145 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2146 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2160 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2167 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2179 returned 0 features. Skipping because I dont know what to do with this

# %%
cleaned_attribs = {k: v.split('/')[-1] for k, v in attribs.items()}
print(f'Found {len(cleaned_attribs)} NHD matches')
# Out:
# Found 474 NHD matches

# %%
df['nhdv2_comid'] = df.index.map(cleaned_attribs)

# %%
print(f'{len(df[df.nhdv2_comid.isna()])} are still unknown')
# Out:
# 65 are still unknown

# %% [markdown]
# Many gauges were not intersecting with NHD features. Increase the buffer for these location and try again.

# %%
attribs, errors = get_geoconnex_metadata(df[df.nhdv2_comid.isna()],
                                        'mainstems',
                                         'head_nhdpv2_comid',
                                         buffer=0.01)
# Out:
#   0%|          | 0/139 [00:00<?, ?it/s]
# Gauge STREAM-gauge-1637 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1645 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1646 returned 3 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1666 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1670 returned 3 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1692 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1693 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1704 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1708 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1711 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1712 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1717 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1718 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1719 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1726 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1734 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1743 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1744 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1762 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1779 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1798 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1804 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1810 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1830 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1838 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1842 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1868 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1881 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1882 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1887 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1895 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1897 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1900 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1908 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1915 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1918 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1921 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1931 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1938 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1943 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1953 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1957 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1969 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1970 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1971 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1972 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1984 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1987 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1991 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-1998 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2028 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2038 returned 3 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2042 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2043 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2044 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2050 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2057 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2058 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2060 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2072 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2085 returned 2 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2104 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2112 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2113 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2114 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2141 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2144 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2145 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2167 returned 0 features. Skipping because I dont know what to do with this
# Gauge STREAM-gauge-2179 returned 0 features. Skipping because I dont know what to do with this

# %%
cleaned_attribs = {k: v.split('/')[-1] for k, v in attribs.items()}
print(f'Found {len(cleaned_attribs)} NHD matches')
# Out:
# Found 69 NHD matches

# %%
# Only update rows where new_values is not NaN
new_values= df.index.map(cleaned_attribs)
mask = ~pandas.isna(new_values)
df.loc[mask, 'nhdv2_comid'] = new_values[mask]

# %%
print(f'{len(df[df.nhdv2_comid.isna()])} are still unknown')
# Out:
# 70 are still unknown

# %%
df = df.drop(columns='geometry')
df
# Out:
#              STREAM_ID      SourceID  \
# 0    STREAM-gauge-1616      01427195
# 1    STREAM-gauge-1617      01427207
# 2    STREAM-gauge-1618      01427510
# 3    STREAM-gauge-1619      01428750
# 4    STREAM-gauge-1620      01429000
# ..                 ...           ...
# 534  STREAM-gauge-2175  99410012-001
# 535  STREAM-gauge-2176  99416516-001
# 536  STREAM-gauge-2177  99681726-001
# 537  STREAM-gauge-2178  99685860-001
# 538  STREAM-gauge-2179  99687232-001
#
#                                             site name  \
# 0                  Equinunk Creek near Dillontown, PA
# 1                      DELAWARE RIVER AT LORDVILLE NY
# 2                      DELAWARE RIVER AT CALLICOON NY
# 3    West Branch Lackawaxen River near Aldenville, PA
# 4        West Branch Lackawaxen River at Prompton, PA
# ..                                                ...
# 534                  Pigeon Creek DWS Bentleyville Rd
# 535                          Smith Creek UPS Cook Ave
# 536                 Raccoon Creek at Golf Course Road
# 537                            Traverse Creek at SR18
# 538                     Campbells Run at Brookside Dr
#
#                                                 source  latitude_wgs84  \
# 0                                                 USGS       41.840278
# 1                                                 USGS       41.867278
# 2                                                 USGS       41.756750
# 3                                                 USGS       41.674530
# 4                                                 USGS       41.587218
# ..                                                 ...             ...
# 534  Pennsylvania Department of Environmental Prote...       40.138665
# 535  Pennsylvania Department of Environmental Prote...       39.889337
# 536  Pennsylvania Department of Environmental Prote...       40.608930
# 537  Pennsylvania Department of Environmental Prote...       40.503509
# 538  Pennsylvania Department of Environmental Prote...       40.424985
#
#      longitude_wgs84 State Code         State  drainagearea_sqkm   huc06  \
# 0         -75.238333         PA  Pennsylvania         121.470531  020401
# 1         -75.213750         PA  Pennsylvania        4118.084100  020401
# 2         -75.057417         PA  Pennsylvania        4713.781800  020401
# 3         -75.376013         PA  Pennsylvania         105.153594  020401
# 4         -75.326829         PA  Pennsylvania         154.622403  020401
# ..               ...        ...           ...                ...     ...
# 534       -79.983799         PA  Pennsylvania         106.710000  050200
# 535       -80.185112         PA  Pennsylvania          27.700000  050200
# 536       -80.301372         PA  Pennsylvania         445.000000  050301
# 537       -80.423835         PA  Pennsylvania          37.800000  050301
# 538       -80.108260         PA  Pennsylvania           7.100000  050301
#
#             huc12 nhdv2_comid
# 0    020401010402     2617668
# 1    020401010406     2612780
# 2    020401010506     2612780
# 3    020401030103     2739724
# 4    020401030103     2739724
# ..            ...         ...
# 534  050200050804     3786421
# 535  050200050305     3788563
# 536  050301010207     3823425
# 537  050301010205     3820555
# 538  050301010107         NaN
#
# [539 rows x 12 columns]

# %%
df.to_parquet('data_parquet/metadata.parquet')
