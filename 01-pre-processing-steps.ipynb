# %% [markdown]
# ## Create GIS Layers

# %%
import s3fs
import pandas
import geopandas
from pathlib import Path

import utils.S3hsclient as hsclient

# %%
df = pandas.read_csv("data/01_metadata.csv")

# %%
gdf = geopandas.GeoDataFrame(
    df,
    geometry=geopandas.points_from_xy(df['longitude_wgs84'], df['latitude_wgs84']),
    crs='EPSG:4326' # WGS 84
)

# save to parquet 
gdf.to_parquet('data_parquet/metadata.parquet', index=False)

# %%
gdf = gdf.rename(columns={"latitude_wgs84": "latitude", "longitude_wgs84": "longitude", "drainagearea_sqkm": "drain_sqkm" })

# %%
gdf.to_file("gis/gauges.shp")

# %% [markdown]
# ## Convert Shapefile Points into Parquet

# %%
gdf = geopandas.read_file('gis/gauges.shp')

# %%
gdf.to_parquet('data_parquet/gauges.parquet')

# %%
# read the data from HydroShare

# %% [markdown]
# ## Create Parquet Files

# %%
def create_parquet(input_data_dir, output_filename, date_cols=[], sort_by=None):
    quality_dir = Path(input_data_dir)
    dfs = []
    for f in quality_dir.glob('*.csv'):
        df_temp = pandas.read_csv(f,
                                 parse_dates=date_cols)
        df_temp['gauge'] = f.stem
        dfs.append(df_temp)
        
    df = pandas.concat(dfs)
    
    if sort_by is not None:
        df.sort_values(by=sort_by, inplace=True)
    
    df.to_parquet(output_filename, index=False)

# %%
create_parquet('data/07_lulc', 'data_parquet/lulc.parquet', date_cols=['year'])
create_parquet('data/08_dynamic_anthropogenic', 'data_parquet/dynamic_antropogenic.parquet', date_cols=['year'])
create_parquet('data/02_waterquality_timeseries', 'data_parquet/water_quality.parquet', date_cols=['DateTime'], sort_by='DateTime')
# Out:
# /var/folders/kp/sy5g3vyx7zx1mnfhv7x_rdwr0000gp/T/ipykernel_1674/2279553665.py:5: DtypeWarning: Columns (4,6,8,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pandas.read_csv(f,
# /var/folders/kp/sy5g3vyx7zx1mnfhv7x_rdwr0000gp/T/ipykernel_1674/2279553665.py:5: DtypeWarning: Columns (10,12,14,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pandas.read_csv(f,
# /var/folders/kp/sy5g3vyx7zx1mnfhv7x_rdwr0000gp/T/ipykernel_1674/2279553665.py:5: DtypeWarning: Columns (6,8,10,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pandas.read_csv(f,
# /var/folders/kp/sy5g3vyx7zx1mnfhv7x_rdwr0000gp/T/ipykernel_1674/2279553665.py:5: DtypeWarning: Columns (4,6,8,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pandas.read_csv(f,
# /var/folders/kp/sy5g3vyx7zx1mnfhv7x_rdwr0000gp/T/ipykernel_1674/2279553665.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temp = pandas.read_csv(f,

# %%
create_parquet('data/05_dynamic_historical_meteorology', 'data_parquet/dynamic_historical_meteorology.parquet', date_cols=['time'], sort_by='time')

# %%
create_parquet('data/09_streamflow_discharge', 'data_parquet/streamflow.parquet', date_cols=['DateTime'], sort_by='DateTime')

# %%
create_parquet('data/10_grab_samples', 'data_parquet/grab_samples.parquet', date_cols=['DateTime'], sort_by='DateTime')

# %% [markdown]
# ## Query Parquet Data

# %%
import pyarrow.parquet as pq
from datetime import datetime

# %%
file_path = 'water_quality.parquet'

# %%
gauge = 'STREAM-gauge-1665'
st = datetime(2018, 10, 1)
et = datetime(2020, 3, 1)

table = pq.read_table(
    file_path,
    filters = [
        ('gauge', '=', gauge),
        #('DateTime', '>=', st),
        #('DateTime', '<=', et)
    ]
)

# %%
subset = table.to_pandas()
subset.to_csv('water_quality_subset.csv', index=False)

# %% [markdown]
# ## Misc

# %%
hs = hsclient.S3HydroShare()
# Out:
# Username:  TonyCastronova
# Password for TonyCastronova:  ········

# %%
resource_id = '248ec0f13d6c4580b2faa66425cb58c3'
s3_path = f'tonycastronova/{resource_id}/data/contents/gauges.parquet'

# %%
resource = hs.resource(resource_id)

# %%
resource.s3_ls()
# Out:
# ['tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/dynamic_antropogenic.parquet',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/gauges.parquet',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/gis',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/grab_samples.parquet',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/lulc.parquet',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/streamflow.parquet',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/water_quality.parquet']

# %%
df = geopandas.read_parquet(
    s3_path,
    filesystem=hs.get_s3_filesystem(),
)

# %%
df
# Out:
#             STREAM_ID  SourceID  \
# 0   STREAM-gauge-1616   1427195
# 1   STREAM-gauge-1617   1427207
# 2   STREAM-gauge-1618   1427510
# 3   STREAM-gauge-1619   1428750
# 4   STREAM-gauge-1620   1429000
# 5   STREAM-gauge-1621   1431500
# 6   STREAM-gauge-1622   1432055
# 7   STREAM-gauge-1623   1432110
# 8   STREAM-gauge-1624   1432160
# 9   STREAM-gauge-1625   1432495
# 10  STREAM-gauge-1626   1432805
# 11  STREAM-gauge-1627   1434000
# 12  STREAM-gauge-1628   1439500
# 13  STREAM-gauge-1629   1440400
# 14  STREAM-gauge-1630   1447500
# 15  STREAM-gauge-1631   1447720
# 16  STREAM-gauge-1632   1447800
# 17  STREAM-gauge-1633   1449360
# 18  STREAM-gauge-1634   1449800
# 19  STREAM-gauge-1635   1451380
# 20  STREAM-gauge-1636   1451400
# 21  STREAM-gauge-1637   1451467
# 22  STREAM-gauge-1638   1451500
# 23  STREAM-gauge-1639   1451630
# 24  STREAM-gauge-1640   1451650
# 25  STREAM-gauge-1641   1451800
# 26  STREAM-gauge-1642   1454700
# 27  STREAM-gauge-1643   1462000
# 28  STREAM-gauge-1644   1465500
# 29  STREAM-gauge-1645   1465798
# 30  STREAM-gauge-1646  14670261
# 31  STREAM-gauge-1647   1467042
# 32  STREAM-gauge-1648   1467048
# 33  STREAM-gauge-1649   1467086
# 34  STREAM-gauge-1650   1467087
# 35  STREAM-gauge-1651   1467200
# 36  STREAM-gauge-1652   1468500
# 37  STREAM-gauge-1653   1470736
# 38  STREAM-gauge-1654   1470779
# 39  STREAM-gauge-1655   1470960
# 40  STREAM-gauge-1656   1471875
# 41  STREAM-gauge-1657   1472104
# 42  STREAM-gauge-1658   1472157
# 43  STREAM-gauge-1659   1473000
# 44  STREAM-gauge-1660   1473169
# 45  STREAM-gauge-1661   1473470
# 46  STREAM-gauge-1662   1473500
# 47  STREAM-gauge-1663   1473900
# 48  STREAM-gauge-1664   1474000
# 49  STREAM-gauge-1665   1474500
#
#                                             site_name source   latitude  \
# 0                  Equinunk Creek near Dillontown, PA   USGS  41.840278
# 1                      DELAWARE RIVER AT LORDVILLE NY   USGS  41.867278
# 2                      DELAWARE RIVER AT CALLICOON NY   USGS  41.756750
# 3    West Branch Lackawaxen River near Aldenville, PA   USGS  41.674530
# 4        West Branch Lackawaxen River at Prompton, PA   USGS  41.587218
# 5                      Lackawaxen River at Hawley, PA   USGS  41.476200
# 6                     Lackawaxen River near Baoba, PA   USGS  41.469417
# 7                     Lackawaxen River at Rowland, PA   USGS  41.475923
# 8                     DELAWARE RIVER AT BARRYVILLE NY   USGS  41.474833
# 9                  Shohola Creek near Walker Lake, PA   USGS  41.450000
# 10                     DELAWARE RIVER AT POND EDDY NY   USGS  41.438750
# 11                   DELAWARE RIVER AT PORT JERVIS NY   USGS  41.370583
# 12                        Bush Kill at Shoemakers, PA   USGS  41.088151
# 13                  Brodhead Creek near Analomink, PA   USGS  41.084815
# 14                 Lehigh River at Stoddartsville, PA   USGS  41.130279
# 15                 Tobyhanna Creek near Blakeslee, PA   USGS  41.084724
# 16  Lehigh R bl Francis E Walter Res nr White Have...   USGS  41.104724
# 17                  Pohopoco Creek at Kresgeville, PA   USGS  40.897592
# 18    Pohopoco Cr bl Beltzville Dam nr Parryville, PA   USGS  40.845648
# 19           Little Lehigh Creek near Trexlertown, PA   USGS  40.531119
# 20                    Spring Creek at Trexlertown, PA   USGS  40.534083
# 21                        Leibert Creek at Emmaus, PA   USGS  40.521611
# 22             Little Lehigh Creek near Allentown, PA   USGS  40.582320
# 23            Cedar Creek at Mouth near Allentown, PA   USGS  40.587500
# 24  Little Lehigh Creek at Tenth St. Br. at Allentown   USGS  40.596486
# 25                Jordan Creek near Schnecksville, PA   USGS  40.661762
# 26                        Lehigh River at Glendon, PA   USGS  40.669266
# 27                  Delaware River at Lambertville NJ   USGS  40.364722
# 28                 Neshaminy Creek near Langhorne, PA   USGS  40.173998
# 29  Poquessing Creek at Grant Ave. at Philadelphia...   USGS  40.056956
# 30               Delaware River at Pennypack Woods PA   USGS  40.038500
# 31  Pennypack Creek at Pine Road, at Philadelphia, PA   USGS  40.089733
# 32     Pennypack Cr at Lower Rhawn St Bdg, Phila., PA   USGS  40.050012
# 33     Tacony Creek ab Adams Avenue, Philadelphia, PA   USGS  40.042612
# 34    Frankford Creek at Castor Ave, Philadelphia, PA   USGS  40.015945
# 35  Delaware River at Penn's Landing, Philadelphia...   USGS  39.946402
# 36               Schuylkill River at Landingville, PA   USGS  40.629258
# 37      Sacony Creek at Normal Avenue at Kutztown, PA   USGS  40.515611
# 38               Tulpehocken Creek near Bernville, PA   USGS  40.413344
# 39  Tulpehocken Cr at Blue Marsh Damsite near Reading   USGS  40.370567
# 40               Manatawny Creek near Spangsville, PA   USGS  40.339538
# 41    Schuylkill River at Vincent Dam at Linfield, PA   USGS  40.206212
# 42                 French Creek near Phoenixville, PA   USGS  40.151491
# 43                  Perkiomen Creek at Graterford, PA   USGS  40.229547
# 44   Valley Creek at PA Turnpike Br near Valley Forge   USGS  40.079274
# 45  Stony Creek at Sterigere Street at Norristown, PA   USGS  40.127330
# 46                 Schuylkill River at Norristown, PA   USGS  40.115556
# 47           Wissahickon Creek at Fort Washington, PA   USGS  40.123999
# 48       Wissahickon Creek at Mouth, Philadelphia, PA   USGS  40.015290
# 49               Schuylkill River at Philadelphia, PA   USGS  39.967791
#
#     longitude state_code         State    drain_sqkm  \
# 0  -75.238333         PA  Pennsylvania    121.470531
# 1  -75.213750         PA  Pennsylvania   4118.084100
# 2  -75.057417         PA  Pennsylvania   4713.781800
# 3  -75.376013         PA  Pennsylvania    105.153594
# 4  -75.326829         PA  Pennsylvania    154.622403
# 5  -75.172119         PA  Pennsylvania    751.097100
# 6  -75.108944         PA  Pennsylvania   1403.774580
# 7  -75.036281         PA  Pennsylvania   1525.504110
# 8  -74.913250         PA  Pennsylvania   6886.783410
# 9  -74.921667         PA  Pennsylvania    192.954255
# 10 -74.819139         PA  Pennsylvania   7303.771800
# 11 -74.697139         PA  Pennsylvania   7966.809240
# 12 -75.037675         PA  Pennsylvania    303.028830
# 13 -75.214625         PA  Pennsylvania    170.680341
# 14 -75.625453         PA  Pennsylvania    237.502083
# 15 -75.605452         PA  Pennsylvania    305.618820
# 16 -75.732123         PA  Pennsylvania    751.097100
# 17 -75.502408         PA  Pennsylvania    129.240501
# 18 -75.645744         PA  Pennsylvania    249.675036
# 19 -75.600455         PA  Pennsylvania     55.166787
# 20 -75.601472         PA  Pennsylvania     61.382763
# 21 -75.508333         PA  Pennsylvania     10.308160
# 22 -75.482961         PA  Pennsylvania    209.271192
# 23 -75.496806         PA  Pennsylvania     37.554855
# 24 -75.474072         PA  Pennsylvania    254.337018
# 25 -75.626854         PA  Pennsylvania    137.269470
# 26 -75.236288         PA  Pennsylvania   3519.796410
# 27 -74.948889         PA  Pennsylvania  17301.133200
# 28 -74.956834         PA  Pennsylvania    543.897900
# 29 -74.985160         PA  Pennsylvania     55.425786
# 30 -74.993611         PA  Pennsylvania  20201.922000
# 31 -75.069052         PA  Pennsylvania     98.160621
# 32 -75.032662         PA  Pennsylvania    128.981502
# 33 -75.112119         PA  Pennsylvania     43.252833
# 34 -75.096841         PA  Pennsylvania     78.735696
# 35 -75.139360         PA  Pennsylvania  20701.790070
# 36 -76.124662         PA  Pennsylvania    344.468670
# 37 -75.770194         PA  Pennsylvania     52.835796
# 38 -76.171585         PA  Pennsylvania    182.335296
# 39 -76.025192         PA  Pennsylvania    453.248250
# 40 -75.742136         PA  Pennsylvania    147.370431
# 41 -75.565463         PA  Pennsylvania   3079.498110
# 42 -75.601305         PA  Pennsylvania    153.068409
# 43 -75.451567         PA  Pennsylvania    722.607210
# 44 -75.460748         PA  Pennsylvania     53.871792
# 45 -75.344905         PA  Pennsylvania     52.835796
# 46 -75.356111         PA  Pennsylvania   4558.382400
# 47 -75.219899         PA  Pennsylvania    105.671592
# 48 -75.206834         PA  Pennsylvania    165.759360
# 49 -75.188501         PA  Pennsylvania   4902.851070
#
#                       geometry
# 0   POINT (-75.23833 41.84028)
# 1   POINT (-75.21375 41.86728)
# 2   POINT (-75.05742 41.75675)
# 3   POINT (-75.37601 41.67453)
# 4   POINT (-75.32683 41.58722)
# 5    POINT (-75.17212 41.4762)
# 6   POINT (-75.10894 41.46942)
# 7   POINT (-75.03628 41.47592)
# 8   POINT (-74.91325 41.47483)
# 9      POINT (-74.92167 41.45)
# 10  POINT (-74.81914 41.43875)
# 11  POINT (-74.69714 41.37058)
# 12  POINT (-75.03768 41.08815)
# 13  POINT (-75.21462 41.08482)
# 14  POINT (-75.62545 41.13028)
# 15  POINT (-75.60545 41.08472)
# 16  POINT (-75.73212 41.10472)
# 17  POINT (-75.50241 40.89759)
# 18  POINT (-75.64574 40.84565)
# 19  POINT (-75.60046 40.53112)
# 20  POINT (-75.60147 40.53408)
# 21  POINT (-75.50833 40.52161)
# 22  POINT (-75.48296 40.58232)
# 23   POINT (-75.49681 40.5875)
# 24  POINT (-75.47407 40.59649)
# 25  POINT (-75.62685 40.66176)
# 26  POINT (-75.23629 40.66927)
# 27  POINT (-74.94889 40.36472)
# 28    POINT (-74.95683 40.174)
# 29  POINT (-74.98516 40.05696)
# 30   POINT (-74.99361 40.0385)
# 31  POINT (-75.06905 40.08973)
# 32  POINT (-75.03266 40.05001)
# 33  POINT (-75.11212 40.04261)
# 34  POINT (-75.09684 40.01594)
# 35   POINT (-75.13936 39.9464)
# 36  POINT (-76.12466 40.62926)
# 37  POINT (-75.77019 40.51561)
# 38  POINT (-76.17158 40.41334)
# 39  POINT (-76.02519 40.37057)
# 40  POINT (-75.74214 40.33954)
# 41  POINT (-75.56546 40.20621)
# 42   POINT (-75.6013 40.15149)
# 43  POINT (-75.45157 40.22955)
# 44  POINT (-75.46075 40.07927)
# 45   POINT (-75.3449 40.12733)
# 46  POINT (-75.35611 40.11556)
# 47     POINT (-75.2199 40.124)
# 48  POINT (-75.20683 40.01529)
# 49   POINT (-75.1885 39.96779)
