# %% [markdown]
# # Map Prototype
#
# This notebook launches a prototype map interface for accessing STREAM data. To ensure that this code works as expected, it is recommended that you install its dependencies using the following command.

# %%
# !pip install -q -r requirements.txt
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# If packages were installed, it's best to restart the environment to ensure that everything is loaded properly. This can be done by clicking the ![image.png](attachment:d70fc856-f010-4dc8-93a0-eaddb236f903.png) button in the Jupyter toolbar.

# %%
from utils import streams
m = streams.StreamsMap()
# Out:
# Please Enter Your HydroShare Credentials
# Username:  TonyCastronova
# Password for TonyCastronova:  ········

# %%
#m.asInlineMap()
m.asSideCarMap()
# Out:
# HTML(value='\n            <style>\n                .fa-circle-o-notch, .fa-refresh, .fa-cog {\n               …
