# %% [markdown]
# # This Notebook Documents How Data was Uploaded to HydroShare

# %%
from utils import S3hsclient as hsclient

# %%
# Sign in to HydroShare using the hsclient library
# This will prompt you to enter your username and password
hs = hsclient.S3HydroShare()
# Out:
# Username:  TonyCastronova
# Password for TonyCastronova:  ········

# %% [markdown]
# Load the HydroShare resource containing our files: https://hydroshare.org/resource/248ec0f13d6c4580b2faa66425cb58c3/

# %%
resource_id = '248ec0f13d6c4580b2faa66425cb58c3'
resource = hs.resource(resource_id)

# %% [markdown]
# List the files that exist in this resource.

# %%
resource.s3_ls(prefix='')
# Out:
# ['tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/dynamic_antropogenic.parquet',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/dynamic_historical_meteorology',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/dynamic_historical_meteorology.zip',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/gauges.cpg',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/gauges.dbf',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/gauges.parquet',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/gauges.prj',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/gauges.shp',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/gauges.shx',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/gauges_meta.xml',
#  'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/gauges_resmap.xml',
# ...

# %%
#resource._hs_session.s3.rm('tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/dynamic_historical_meteorology')

# %%
resource._hs_session.s3.put('data_parquet/dynamic_historical_meteorology',
                            'tonycastronova/248ec0f13d6c4580b2faa66425cb58c3/data/contents/dynamic_historical_meteorology',
                           recursive=True)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
# def upload_data(filepath, file_name):
#     s3 = s3fs.S3FileSystem()
#     s3_path = f"name-of-my-bucket/{file_name}"
#     s3.put(filepath, s3_path, recursive=True)
